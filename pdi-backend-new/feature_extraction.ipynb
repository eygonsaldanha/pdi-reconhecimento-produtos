# %%
import sys
from feature_extraction import extract_features, extract_features_from_dataset
from preprocessing import load_dataset

sys.path.append("..")

# %%
q_images_test = 10

print("Carregando dataset...")
images, labels, classes = load_dataset("../dataset", size=(128, 128))

print("Extraindo características da primeira imagem...")
features = extract_features(images[0])
print(f"Tamanho do vetor de características: {len(features)}")
print(f"Total esperado: {8*8*8 + 256} features")

print("Extraindo características de todas as imagens...")
X = extract_features_from_dataset(images[:q_images_test])
print(f"Shape da matriz de características: {X.shape}")
# Out:
# Carregando dataset...
# Carregando classe: Apple
#   -> 804 imagens carregadas
# Carregando classe: Banana
#   -> 804 imagens carregadas
# Carregando classe: Coco
#   -> 800 imagens carregadas
# Carregando classe: Passion Fruit
#   -> 800 imagens carregadas
# Carregando classe: Pineapple
#   -> 803 imagens carregadas
# Carregando classe: Strawberry
#   -> 803 imagens carregadas
# Carregando classe: Watermelon
#   -> 800 imagens carregadas
#
# Total: 5614 imagens de 7 classes
# Classes: ['Apple', 'Banana', 'Coco', 'Passion Fruit', 'Pineapple', 'Strawberry', 'Watermelon']
# Extraindo características da primeira imagem...
# Tamanho do vetor de características: 768
# Total esperado: 768 features
# Extraindo características de todas as imagens...
# Extração completa: 10 imagens
# Shape da matriz de características: (10, 768)
