# %%
from train import *
import numpy as np
import joblib
from pathlib import Path
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV, cross_val_score
from typing import Tuple, Dict, Any
import time
from datetime import timedelta

from preprocessing import load_dataset
from feature_extraction import extract_features_from_dataset

# %%
classifier = FruitClassifier(image_size=(128, 128))

# %%
X_train, y_train = classifier.prepare_data("../dataset")
# Out:
# Carregando classe: Apple
#   -> 804 imagens carregadas
# Carregando classe: Banana
#   -> 804 imagens carregadas
# Carregando classe: Coco
#   -> 800 imagens carregadas
# Carregando classe: Passion Fruit
#   -> 800 imagens carregadas
# Carregando classe: Pineapple
#   -> 803 imagens carregadas
# Carregando classe: Strawberry
#   -> 803 imagens carregadas
# Carregando classe: Watermelon
#   -> 800 imagens carregadas
#
# Total: 5614 imagens de 7 classes
# Classes: ['Apple', 'Banana', 'Coco', 'Passion Fruit', 'Pineapple', 'Strawberry', 'Watermelon']
# Extraindo características: 50/5614
# Extraindo características: 100/5614
# Extraindo características: 150/5614
# Extraindo características: 200/5614
# Extraindo características: 250/5614
# Extraindo características: 300/5614
# Extraindo características: 350/5614
# Extraindo características: 400/5614
# Extraindo características: 450/5614
# Extraindo características: 500/5614
# Extraindo características: 550/5614
# Extraindo características: 600/5614
# Extraindo características: 650/5614
# Extraindo características: 700/5614
# Extraindo características: 750/5614
# Extraindo características: 800/5614
# Extraindo características: 850/5614
# Extraindo características: 900/5614
# Extraindo características: 950/5614
# Extraindo características: 1000/5614
# Extraindo características: 1050/5614
# Extraindo características: 1100/5614
# Extraindo características: 1150/5614
# Extraindo características: 1200/5614
# Extraindo características: 1250/5614
# Extraindo características: 1300/5614
# Extraindo características: 1350/5614
# Extraindo características: 1400/5614
# Extraindo características: 1450/5614
# Extraindo características: 1500/5614
# Extraindo características: 1550/5614
# Extraindo características: 1600/5614
# Extraindo características: 1650/5614
# Extraindo características: 1700/5614
# Extraindo características: 1750/5614
# Extraindo características: 1800/5614
# Extraindo características: 1850/5614
# Extraindo características: 1900/5614
# Extraindo características: 1950/5614
# Extraindo características: 2000/5614
# Extraindo características: 2050/5614
# Extraindo características: 2100/5614
# Extraindo características: 2150/5614
# Extraindo características: 2200/5614
# Extraindo características: 2250/5614
# Extraindo características: 2300/5614
# Extraindo características: 2350/5614
# Extraindo características: 2400/5614
# Extraindo características: 2450/5614
# Extraindo características: 2500/5614
# Extraindo características: 2550/5614
# Extraindo características: 2600/5614
# Extraindo características: 2650/5614
# Extraindo características: 2700/5614
# Extraindo características: 2750/5614
# Extraindo características: 2800/5614
# Extraindo características: 2850/5614
# Extraindo características: 2900/5614
# Extraindo características: 2950/5614
# Extraindo características: 3000/5614
# Extraindo características: 3050/5614
# Extraindo características: 3100/5614
# Extraindo características: 3150/5614
# Extraindo características: 3200/5614
# Extraindo características: 3250/5614
# Extraindo características: 3300/5614
# Extraindo características: 3350/5614
# Extraindo características: 3400/5614
# Extraindo características: 3450/5614
# Extraindo características: 3500/5614
# Extraindo características: 3550/5614
# Extraindo características: 3600/5614
# Extraindo características: 3650/5614
# Extraindo características: 3700/5614
# Extraindo características: 3750/5614
# Extraindo características: 3800/5614
# Extraindo características: 3850/5614
# Extraindo características: 3900/5614
# Extraindo características: 3950/5614
# Extraindo características: 4000/5614
# Extraindo características: 4050/5614
# Extraindo características: 4100/5614
# Extraindo características: 4150/5614
# Extraindo características: 4200/5614
# Extraindo características: 4250/5614
# Extraindo características: 4300/5614
# Extraindo características: 4350/5614
# Extraindo características: 4400/5614
# Extraindo características: 4450/5614
# Extraindo características: 4500/5614
# Extraindo características: 4550/5614
# Extraindo características: 4600/5614
# Extraindo características: 4650/5614
# Extraindo características: 4700/5614
# Extraindo características: 4750/5614
# Extraindo características: 4800/5614
# Extraindo características: 4850/5614
# Extraindo características: 4900/5614
# Extraindo características: 4950/5614
# Extraindo características: 5000/5614
# Extraindo características: 5050/5614
# Extraindo características: 5100/5614
# Extraindo características: 5150/5614
# Extraindo características: 5200/5614
# Extraindo características: 5250/5614
# Extraindo características: 5300/5614
# Extraindo características: 5350/5614
# Extraindo características: 5400/5614
# Extraindo características: 5450/5614
# Extraindo características: 5500/5614
# Extraindo características: 5550/5614
# Extraindo características: 5600/5614
# Extração completa: 5614 imagens

# %%
best_params = classifier.tune_hyperparameters(X_train, y_train, cv=5)

classifier.train(X_train, y_train, params=best_params)

classifier.save_model("../models/knn_model.pkl")
# Out:
# ============================================================
# AJUSTE DE HIPERPARÂMETROS
# ============================================================
# Testando 30 combinações...
# Parâmetros: {'n_neighbors': [3, 5, 7, 9, 11], 'weights': ['uniform', 'distance'], 'metric': ['euclidean', 'manhattan', 'minkowski']}
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
#
# Tempo de busca: 15.16s
#
# Melhores parâmetros: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# Melhor acurácia (CV): 0.6667
#
# Parâmetros do modelo: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# Tempo de treinamento: 0.00s
# Cross-validation (5-fold):
#   - Acurácia média: 0.6667
#   - Desvio padrão: 0.0145
#   - Scores: [0.69100623 0.66696349 0.64915405 0.67141585 0.65508021]
#
# ============================================================
# MODELO SALVO: ../models/knn_model.pkl
# ============================================================
